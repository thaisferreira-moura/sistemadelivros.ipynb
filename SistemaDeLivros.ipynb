# %%
# Lista que armazenará os livros
livros = []

while True:
    print("\n====== SISTEMA DE BIBLIOTECA ======")
    print("1 - Cadastrar Livro")
    print("2 - Listar Livros")
    print("3 - Buscar Livro")
    print("4 - Excluir Livro")
    print("5 - Sair")

    opcao = input("Escolha uma opção: ")

    if opcao == "1":
        print("\n=== Cadastro ===")

        titulo = input("Título: ").strip()
        autor = input("Autor: ").strip()

        while True:
            ano = input("Ano de publicação: ")
            if ano.isdigit():
                ano = int(ano)
                break
            else:
                print("Digite um ano válido!")

        livro = {
            "titulo": titulo,
            "autor": autor,
            "ano": ano
        }

        livros.append(livro)

        print("Livro cadastrado com sucesso!")

    elif opcao == "2":
        print("\n=== Lista de Livros ===")

        if len(livros) == 0:
            print("Nenhum livro cadastrado.")
        else:
            for i, livro in enumerate(livros):
                print(f"\nLivro {i+1}")
                print(f"Título: {livro['titulo']}")
                print(f"Autor: {livro['autor']}")
                print(f"Ano: {livro['ano']}")

    elif opcao == "3":
        print("\n=== Buscar Livro ===")

        busca = input("Digite o título: ").strip()

        encontrado = False

        for livro in livros:
            if livro["titulo"].lower() == busca.lower():
                print("\nLivro encontrado!")
                print(f"Título: {livro['titulo']}")
                print(f"Autor: {livro['autor']}")
                print(f"Ano: {livro['ano']}")
                encontrado = True

        if not encontrado:
            print("Livro não encontrado.")

    elif opcao == "4":
        print("\n=== Excluir Livro ===")

        busca = input("Digite o título do livro: ").strip()

        encontrado = False

        for livro in livros:
            if livro["titulo"].lower() == busca.lower():
                livros.remove(livro)
                print("Livro removido com sucesso!")
                encontrado = True
                break

        if not encontrado:
            print("Livro não encontrado.")

    elif opcao == "5":
        print("Sistema encerrado.")
        break

    else:
        print("Opção inválida!")
# Out:
# ====== SISTEMA DE BIBLIOTECA ======
# 1 - Cadastrar Livro
# 2 - Listar Livros
# 3 - Buscar Livro
# 4 - Excluir Livro
# 5 - Sair
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_852/829739671.py in <cell line: 0>()
#      10     print("5 - Sair")
#      11
# ---> 12     opcao = input("Escolha uma opção: ")
#      13
#      14     if opcao == "1":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
